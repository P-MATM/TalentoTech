# %% [markdown]
# <a href="https://colab.research.google.com/github/P-MATM/TalentoTech/blob/main/1_Primera_Pr%C3%A1ctica.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ________________________________________________________________________________
#
# #Antes de comenzar, crea una copia del tutorial en nuestra cuenta, para tener nuestra propia versión y modificarla a nuestro antojo.
#
# Vayan a ***Archivo*** -> ***Guardar una copia en Drive***
#
# Se abrirá un nuevo cuaderno de Google Colab donde podrán modificar lo que quieran.
# ________________________________________________________________________________

# %% [markdown]
# # Practica 1: Incluye importar un Dataset

# %%
# Paso 1: Debo traer el archivo en una carpeta
# Paso 2: Debo establecer una conexión con la carpeta
# Paso 3 :Ejecutar la celda de la conexión y revisar que esté Ok

# %% [markdown]
# Conectarse con el drive : Crear la cadena de conexión

# %%
from google.colab import drive #Traemos la clase drive, dentro del módulo Colab, del paquete de Google
drive.mount('/content/drive') # Se establece la conexión a tráves de método mount
# Out:
# Mounted at /content/drive

# %% [markdown]
# Ruta para conectarme a un archivo de Drive

# %%
path = '/content/drive/MyDrive/Talento Tech/Ventas.xlsx'

# %% [markdown]
# Usar librería PANDAS para el manejo y lectura de los datos del archivo

# %%
import pandas as pd

# A partir de ahora la librería PANDAS será llamada pd

# %% [markdown]
# Crar un Dataframe a partir del archivo xlsx (Excel)

# %%
''' 1. Convertir el archivo plano de Excel, a un archivo de Pandas, un Dataframe de Pandas

2. Usando el lector del archivos de Excel de la librería Pandas:
pd.read_excel()'''

df = pd.read_excel(path)

# %% [markdown]
# ____________________________________________
# # Creación y lectura de DataFrames:
#
#
#
# *   pd.DataFrame(data) : Crea un DataFrame a partir de datos.
# *   pd.red_csv('archivo.csv') : Lee un archivo CSV y crea un DataFrame.
# *   pd.read_excel('archivo.xlsx') : Lee un archivo Excel y crea un DataFrame.

# %% [markdown]
# # Visualización y exploración de datos:
#
#
# *   df.head(): Muestra las primeras filas del DataFrame.
# *   df.tail() : Muestas las últimas filas del DataFrame.
# *   df.info() : Muestra información sobre el DataFrame, inculendo tipos de datos y valores no nulos.
# *   df.describe() : Proporciona estadísticas para columnas numéricas.
# *   df.shape : Devuelve una tupla con la cantiddad de filas y columnas del DataFrame.
# *   df.columns : Decuelve una lista con los nombres de las columnas del DataFrame.
# ____________________________________________

# %% [markdown]
# Presento lo que tengo inicialmente en mi archivo

# %%
df.head()
# Out:
#     Region      Producto Vendedor  Ventas
# 0  Central    Accesorios    David    8287
# 1  Central    Accesorios    Karen    6909
# 2  Central  Dispositivos    David   11420
# 3  Central  Dispositivos    Karen   12948
# 4  Central      Sistemas    David   20098

# %%
df.tail()
# Out:
#    Region      Producto Vendedor  Ventas
# 13  Oeste    Accesorios     Sara    5442
# 14  Oeste  Dispositivos    Kevin   10711
# 15  Oeste  Dispositivos     Sara    8780
# 16  Oeste      Sistemas    Kevin   32855
# 17  Oeste      Sistemas     Sara   23151

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Region    18 non-null     object
#  1   Producto  18 non-null     object
#  2   Vendedor  18 non-null     object
#  3   Ventas    18 non-null     int64
# dtypes: int64(1), object(3)
# memory usage: 704.0+ bytes

# %%
df.describe()
# Out:
#              Ventas
# count     18.000000
# mean   13307.388889
# std     8153.055776
# min     4744.000000
# 25%     8410.250000
# 50%    10529.500000
# 75%    13491.750000
# max    32855.000000

# %%
df.shape
# Out:
# (18, 4)

# %%
df.columns
# Out:
# Index(['Region', 'Producto', 'Vendedor', 'Ventas'], dtype='object')

# %% [markdown]
# ___________________________________________________________________________
# # ***Ejercicios:***
# ___________________________________________________________________________

# %%
# Ejercicio 1: Mostrar las primeras filas del DataFrame

print("Ejercicio 1: Mostrar las primeras filas del DataFrame")
print(df.head())
#print("\n")
# Out:
# Ejercicio 1: Mostrar las primeras filas del DataFrame
#     Region      Producto Vendedor  Ventas
# 0  Central    Accesorios    David    8287
# 1  Central    Accesorios    Karen    6909
# 2  Central  Dispositivos    David   11420
# 3  Central  Dispositivos    Karen   12948
# 4  Central      Sistemas    David   20098

# %% [markdown]
# ____________________________________________
# # Agrupar (filtrar) por una categoría (columna): Agrupo, para ver el resumen (valor agrupado, total)  de ventas por región.
#
# *   df.groupby()[].sum()
#
#  (categoría: columna)[varible numérica].sum()
#
# ____________________________________________

# %%
# Ejercicio 2: Calcular el total de ventas por región
print("Ejercicio 2: Calcular el total de ventas por región")
ventas_por_region = df.groupby('Region')['Ventas'].sum()
print(ventas_por_region)
print("\n")
print(df.head(18))
# Out:
# Ejercicio 2: Calcular el total de ventas por región
# Region
# Central    90295
# Este       63555
# Oeste      85683
# Name: Ventas, dtype: int64
#
#
#      Region      Producto Vendedor  Ventas
# 0   Central    Accesorios    David    8287
# 1   Central    Accesorios    Karen    6909
# 2   Central  Dispositivos    David   11420
# 3   Central  Dispositivos    Karen   12948
# 4   Central      Sistemas    David   20098
# 5   Central      Sistemas    Karen   30633
# 6      Este    Accesorios      Ana    9323
# 7      Este    Accesorios    Lucas    7667
# 8      Este  Dispositivos      Ana   10348
# 9      Este  Dispositivos    Lucas    9312
# 10     Este      Sistemas      Ana   13531
# 11     Este      Sistemas    Lucas   13374
# 12    Oeste    Accesorios    Kevin    4744
# 13    Oeste    Accesorios     Sara    5442
# 14    Oeste  Dispositivos    Kevin   10711
# 15    Oeste  Dispositivos     Sara    8780
# 16    Oeste      Sistemas    Kevin   32855
# ...

# %%
# Ejercicio 3: Filtrar el Dataframe para mostrar sólo las ventas realizadas por David
print("Ejercicio 3: Filtrar el Dataframe para mostrar sólo las ventas realizadas por David")
ventas_david = df[df['Vendedor'] == 'David']
print(ventas_david)
print("\n")
# Out:
# Ejercicio 3: Filtrar el Dataframe para mostrar sólo las ventas realizadas por David
#     Region      Producto Vendedor  Ventas
# 0  Central    Accesorios    David    8287
# 2  Central  Dispositivos    David   11420
# 4  Central      Sistemas    David   20098

# %%
# Ejercicio 4: Calcular el promedio de ventas por producto
print("Ejercicio 4: Calcular el promedio de ventas por producto")
ventas_por_producto = df.groupby('Producto')['Ventas'].mean()
print(ventas_por_producto)
print("\n")
# Out:
# Ejercicio 4: Calcular el promedio de ventas por producto
# Producto
# Accesorios       7062.000000
# Dispositivos    10586.500000
# Sistemas        22273.666667
# Name: Ventas, dtype: float64

# %%
# Ejercicio 5: Ordenar el Dataframe por ventas, en orden descendente (Mayor a menor)
print("Ejercicio 5: Ordenar el Dataframe por ventas en orden descendente")
print("\n")
df_ordenado = df.sort_values(by='Ventas',ascending=False)
print(df_ordenado)
# Out:
# Ejercicio 5: Ordenar el Dataframe por ventas en orden descendente
#
#
#      Region      Producto Vendedor  Ventas
# 16    Oeste      Sistemas    Kevin   32855
# 5   Central      Sistemas    Karen   30633
# 17    Oeste      Sistemas     Sara   23151
# 4   Central      Sistemas    David   20098
# 10     Este      Sistemas      Ana   13531
# 11     Este      Sistemas    Lucas   13374
# 3   Central  Dispositivos    Karen   12948
# 2   Central  Dispositivos    David   11420
# 14    Oeste  Dispositivos    Kevin   10711
# 8      Este  Dispositivos      Ana   10348
# 6      Este    Accesorios      Ana    9323
# 9      Este  Dispositivos    Lucas    9312
# 15    Oeste  Dispositivos     Sara    8780
# 0   Central    Accesorios    David    8287
# 7      Este    Accesorios    Lucas    7667
# 1   Central    Accesorios    Karen    6909
# 13    Oeste    Accesorios     Sara    5442
# 12    Oeste    Accesorios    Kevin    4744

# %% [markdown]
# ___________________________________________
# # Manipulación de datos:
#
#
# *   Filtrar las filas donde las ventas sean mayores a 10.000.
# *   Ordena el DataFrame por la columna "Ventas" en orden descendente.
# *   Elimina la columna "Vendedor".
#
# ___________________________________________

# %%
# Ejercicio 6: Filtrar las filas con ventas mayores a 10.000
print('Ejercicio 6: Filtrar las filas con ventas mayores a 10.000')
print("\n")
df_filtrado= df[df['Ventas']>10000]
print(df_filtrado)
print("\n")
# Out:
# Ejercicio 6: Filtrar las filas con ventas mayores a 10.000
#
#
#      Region      Producto Vendedor  Ventas
# 2   Central  Dispositivos    David   11420
# 3   Central  Dispositivos    Karen   12948
# 4   Central      Sistemas    David   20098
# 5   Central      Sistemas    Karen   30633
# 8      Este  Dispositivos      Ana   10348
# 10     Este      Sistemas      Ana   13531
# 11     Este      Sistemas    Lucas   13374
# 14    Oeste  Dispositivos    Kevin   10711
# 16    Oeste      Sistemas    Kevin   32855
# 17    Oeste      Sistemas     Sara   23151

# %%
# Ejercicio 7: Ordenar el DataFrame por ventas en orden descendente
print('Ordenar el DataFrame por ventas en orden descendente')
df_ordenado = df.sort_values(by='Ventas',ascending=False)
print(df_ordenado)
print("\n")

## Ejercicio 7.1: Ordenar el DataFrame por ventas en orden ascendente
print("Ordenar el DataFrame por ventas en orden ascendente")
df_ordenado = df.sort_values(by='Ventas',ascending=True)
print(df_ordenado)
print("\n")

## Ejercicio 7.2: Ordenar el DataFrame por ventas en orden ascendente, sin usar ascending
print("Ordenar el DataFrame por ventas en orden ascendente, sin usar ascending")
#df_ordenado = df.sort_values(by='Ventas',ascending=True)
print(df_ordenado)
print("\n")
# Out:
# Ordenar el DataFrame por ventas en orden descendente
#      Region      Producto Vendedor  Ventas
# 16    Oeste      Sistemas    Kevin   32855
# 5   Central      Sistemas    Karen   30633
# 17    Oeste      Sistemas     Sara   23151
# 4   Central      Sistemas    David   20098
# 10     Este      Sistemas      Ana   13531
# 11     Este      Sistemas    Lucas   13374
# 3   Central  Dispositivos    Karen   12948
# 2   Central  Dispositivos    David   11420
# 14    Oeste  Dispositivos    Kevin   10711
# 8      Este  Dispositivos      Ana   10348
# 6      Este    Accesorios      Ana    9323
# 9      Este  Dispositivos    Lucas    9312
# 15    Oeste  Dispositivos     Sara    8780
# 0   Central    Accesorios    David    8287
# 7      Este    Accesorios    Lucas    7667
# 1   Central    Accesorios    Karen    6909
# 13    Oeste    Accesorios     Sara    5442
# 12    Oeste    Accesorios    Kevin    4744
#
#
# Ordenar el DataFrame por ventas en orden ascendente
# ...

# %%
# Ejercicio 8: Eliminar la columna "Vendedor"
print('Eliminar la columna "Vendedor"')
df_sin_vendedor = df.drop(columns=['Vendedor'])
print(df_sin_vendedor)
print("\n")
# Out:
# Eliminar la columna "Vendedor"
#      Region      Producto  Ventas
# 0   Central    Accesorios    8287
# 1   Central    Accesorios    6909
# 2   Central  Dispositivos   11420
# 3   Central  Dispositivos   12948
# 4   Central      Sistemas   20098
# 5   Central      Sistemas   30633
# 6      Este    Accesorios    9323
# 7      Este    Accesorios    7667
# 8      Este  Dispositivos   10348
# 9      Este  Dispositivos    9312
# 10     Este      Sistemas   13531
# 11     Este      Sistemas   13374
# 12    Oeste    Accesorios    4744
# 13    Oeste    Accesorios    5442
# 14    Oeste  Dispositivos   10711
# 15    Oeste  Dispositivos    8780
# 16    Oeste      Sistemas   32855
# 17    Oeste      Sistemas   23151

# %% [markdown]
# ___________________________________________
# # Agregación y agrupación de datos:
#
#
#
# *   Calcular el total de ventas por región.
# *   Calcular el total de ventas por producto.
#
# ___________________________________________

# %%
# Ejercicio 9: Calcular el total de ventas por región
print("Ejercicio 9: Calcular el total de ventas por región")
ventas_por_region = df.groupby('Region')['Ventas'].sum()
print(ventas_por_region)
print("\n")
# Out:
# Ejercicio 9: Calcular el total de ventas por región
# Region
# Central    90295
# Este       63555
# Oeste      85683
# Name: Ventas, dtype: int64

# %%
# Ejercicio 10: Calcular el total de ventas por producto
print("Ejercicio 10: Calcular el total de ventas por producto")
ventas_por_producto = df.groupby('Producto')['Ventas'].sum()
print(ventas_por_producto)
print("\n")
# Out:
# Ejercicio 10: Calcular el total de ventas por producto
# Producto
# Accesorios       42372
# Dispositivos     63519
# Sistemas        133642
# Name: Ventas, dtype: int64

# %% [markdown]
# _________________________________________
# # Crear un dataframe en pandas, de manera manual
# _________________________________________

# %%
# Crear un DataFrame en Pandas

data = {
    'id : [1,2,3,4,5,3,5]',
    'weight : [144.5,167.2,124.1,144.5,133.2,124.1,129.2]',
    'height : [5.9,5.4,5.2,5.9,5.7,5.2,5.3]',
    'age: [33,45,23,33,54,23,42]',
    'gender : [M,M,F,M,F,F,M]',
}

df_jameboard = pd.DataFrame(data)
print('DataFrame creado a partir de ejercicio del JameBoard')
print(df_jameboard)
# Out:
# DataFrame creado a partir de ejercicio del JameBoard
#                                                    0
# 0                        age: [33,45,23,33,54,23,42]
# 1                           gender : [M,M,F,M,F,F,M]
# 2  weight : [144.5,167.2,124.1,144.5,133.2,124.1,...
# 3                               id : [1,2,3,4,5,3,5]
# 4             height : [5.9,5.4,5.2,5.9,5.7,5.2,5.3]

# %% [markdown]
# ___________________________________________________________________________
# # ***Utilizando el dataframe del jameboard***
# ___________________________________________________________________________

# %%
data2 = {
    'id' : [1,2,3,4,5,3,5,None,None,None],
    'weight' : [144.5,167.2,124.1,144.5,133.2,124.1,129.2,None,None,None],
    'height' : [5.9,5.4,5.2,5.9,5.7,5.2,5.3,None,None,None],
    'age': [33,45,23,33,54,23,42,None,None,None],
    'gender' : ['M','M','F','M','F','F','M',None,None,None]
}

df2_jameboard = pd.DataFrame(data2)
print('***DataFrame creado a partir de ejercicio del JameBoard***')
print(df2_jameboard)
print("\n")
print("***Analizando el contenido del dataframe***")
df2_jameboard.info()
print("\n")
print("***Mostrando los datos como dataframe***")
df2_jameboard.head(10)
# Out:
# ***DataFrame creado a partir de ejercicio del JameBoard***
#     id  weight  height   age gender
# 0  1.0   144.5     5.9  33.0      M
# 1  2.0   167.2     5.4  45.0      M
# 2  3.0   124.1     5.2  23.0      F
# 3  4.0   144.5     5.9  33.0      M
# 4  5.0   133.2     5.7  54.0      F
# 5  3.0   124.1     5.2  23.0      F
# 6  5.0   129.2     5.3  42.0      M
# 7  NaN     NaN     NaN   NaN   None
# 8  NaN     NaN     NaN   NaN   None
# 9  NaN     NaN     NaN   NaN   None
#
#
# ***Analizando el contenido del dataframe***
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      7 non-null      float64
#  1   weight  7 non-null      float64
#  2   height  7 non-null      float64
#  3   age     7 non-null      float64
#  4   gender  7 non-null      object
# dtypes: float64(4), object(1)
# memory usage: 528.0+ bytes
#
#
# ...

# %% [markdown]
# _________________________________________
# # Ejercicio 11 (Adicional)
# * Buscar las filas repetidas con el comando ***duplicates***. Mencionar cuántas filas tenía antes y cuántas tengo después
#
# _________________________________________

# %%
df2_jameboard
# Out:
#     id  weight  height   age gender
# 0  1.0   144.5     5.9  33.0      M
# 1  2.0   167.2     5.4  45.0      M
# 2  3.0   124.1     5.2  23.0      F
# 3  4.0   144.5     5.9  33.0      M
# 4  5.0   133.2     5.7  54.0      F
# 5  3.0   124.1     5.2  23.0      F
# 6  5.0   129.2     5.3  42.0      M
# 7  NaN     NaN     NaN   NaN   None
# 8  NaN     NaN     NaN   NaN   None
# 9  NaN     NaN     NaN   NaN   None

# %% [markdown]
# ***Valores nulos***

# %%
print("*** Conteo de datos nulos ***")
valores_nulos = df2_jameboard.isna().sum()
print(valores_nulos)
# Out:
# *** Conteo de datos nulos ***
# id        3
# weight    3
# height    3
# age       3
# gender    3
# dtype: int64

# %%
# Cantidad de registros antes de aplicar una transformación, limpieza o filtro
print("*** LIMPIEZA DE DATOS ***")
print("********************************************************************")
print(f'Tamaño del dataframe antes de eliminar filas repetidas: {df2_jameboard.shape}')
filas_original = df2_jameboard.shape
n1 = filas_original[0]
# Cantidad de registros después de aplicar una transformación, limpieza o filtro
df2_jameboard.drop_duplicates(inplace=True)
filas_con_limpieza = df2_jameboard.shape
n2 = filas_con_limpieza[0]
print(f'Tamaño del dataframe después de eliminar las filas repetidas: {df2_jameboard.shape}')
print('Se eliminaron: ',n1-n2,' filas repetidas.')
print("********************************************************************")

print("FIN")
# Out:
# *** LIMPIEZA DE DATOS ***
# ********************************************************************
# Tamaño del dataframe antes de eliminar filas repetidas: (10, 5)
# Tamaño del dataframe después de eliminar las filas repetidas: (7, 5)
# Se eliminaron:  3  filas repetidas.
# ********************************************************************
# FIN
